# %% [markdown]
# Q.1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *
#
# 'hello'
#
# -87.8
#
# --
#
# /
#
# +
#
# 6
#
# Ans. Values - 'hello', -87.8, 6 and Expressions - *,-,/,+
#
# ---
#
# Q.2. What is the difference between string and variable?
#
# Ans. Variable stores data/information and string is an information.
#
# ---
#
# Q.3. Describe three different data types.
#
# Ans. Integer - whole numbers, Float - decimal numbers and Boolean - True/False
#
# ---
#
# Q.4. What is an expression made up of? What do all expressions do?
#
# Ans. Made up of operators and operands and produce some value.
#
# ---
#
# Q.5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Q.6 After running the following code, what does the variable bacon contain?
#
# ```
# bacon = 22
# bacon + 1
# ```
#
# Ans. 22
#
# Ans. bacon contains 22 even after executing the code because wee are not updating bacon + 1 in bacon variable.
#
# ---
#
# Q.7. What should the values of the following two terms be?
#
# ```
# python
# 'spam' + 'spamspam'
# 'spam' * 3
# ```
#
# Ans. 'spamspamspam' for both terms.
#
# ---
#
# Q.8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans. Because there are constraints for variable names and one of the constraint is variable name cannot begin with number.
#
# ---
#
# Q.9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Ans. int(), float(), and str() respectively.
#
# ---
#
# Q.10. Why does this expression cause an error? How can you fix it?
#
# ```
# 'I have eaten ' + 99 + ' burritos.'
# ```
#
# Ans. Because 99 in number and we can only add strings to other strings with + operator.
#
# ---
